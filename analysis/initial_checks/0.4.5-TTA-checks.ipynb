# %% [markdown]
# # Running some quick checks on the TTA results

# %% [markdown]
# ## Decoder synchronization training:
#
# I want to check to make sure that the MAE decoding step is not influencing the TTA results by steering the TTA away from the learned representations.
# - train just the decoder for the fully trained models before performing TTA

# %%
from data_management import fetch_dataset_from_hf
from training import decoder_synchronization_training
from model import ClassifierWithTTA
# Out:
# W0922 10:06:34.446000 60292 torch/distributed/elastic/multiprocessing/redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# import error: No module named 'triton'

# %%
model = ClassifierWithTTA.load_from_file('vit2_full/checkpoint-37500/', classifier_hidden_layers=2)
train, val = fetch_dataset_from_hf()
# Out:
# Successfully loaded weights from vit2_full/checkpoint-37500/

# %%
trainer = decoder_synchronization_training(model, train, val, output_dir='vit2_full_sync',
                                           per_device_train_batch_size=128, num_train_epochs=10) #, seed=torch.random.seed())

# %%
import wandb
wandb.init(project="TTA")
trainer.train()
wandb.finish()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: lrast. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/Users/luke/Documents/activeProjects/TTA_working/wandb/run-20250922_100745-0cfurbcu</code>
# Syncing run <strong><a href='https://wandb.ai/lrast/TTA/runs/0cfurbcu' target="_blank">crisp-capybara-102</a></strong> to <a href='https://wandb.ai/lrast/TTA' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/lrast/TTA' target="_blank">https://wandb.ai/lrast/TTA</a>
#  View run at <a href='https://wandb.ai/lrast/TTA/runs/0cfurbcu' target="_blank">https://wandb.ai/lrast/TTA/runs/0cfurbcu</a>
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='7820' max='7820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7820/7820 2:44:50, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.197600</td>
#       <td>0.195336</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.195100</td>
#       <td>0.193302</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.189900</td>
#       <td>0.191277</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.193100</td>
#       <td>0.191231</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.190800</td>
#       <td>0.189679</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.189100</td>
#       <td>0.189671</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.185900</td>
#       <td>0.188218</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.188100</td>
#       <td>0.188797</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.186700</td>
#       <td>0.187544</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.188000</td>
#       <td>0.187970</td>
#     </tr>
#   </tbody>
# </table><p>
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▆▄▄▃▃▂▂▁▁</td></tr><tr><td>eval/runtime</td><td>▄▅▅▁▁█▅▄▃▃</td></tr><tr><td>eval/samples_per_second</td><td>▅▄▄██▁▄▅▆▆</td></tr><tr><td>eval/steps_per_second</td><td>▅▄▄██▁▄▅▆▆</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇█</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>train/grad_norm</td><td>▆▄▄▂▂▁▃▄▂▄▃▅▄▄▃▂▂▄▃▄▃▃▅▃▄▄▃▁▂▂▃▃▄▄▂█▅▃▄▅</td></tr><tr><td>train/learning_rate</td><td>████▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>█▄▄▄▄▄▃▃▃▃▂▃▃▂▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▂▂▂▂▂▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.18797</td></tr><tr><td>eval/runtime</td><td>45.4768</td></tr><tr><td>eval/samples_per_second</td><td>219.892</td></tr><tr><td>eval/steps_per_second</td><td>27.487</td></tr><tr><td>total_flos</td><td>1.0107158003712e+20</td></tr><tr><td>train/epoch</td><td>10</td></tr><tr><td>train/global_step</td><td>7820</td></tr><tr><td>train/grad_norm</td><td>0.16794</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.188</td></tr><tr><td>train_loss</td><td>0.19069</td></tr><tr><td>train_runtime</td><td>9892.2382</td></tr><tr><td>train_samples_per_second</td><td>101.089</td></tr><tr><td>train_steps_per_second</td><td>0.791</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">crisp-capybara-102</strong> at: <a href='https://wandb.ai/lrast/TTA/runs/0cfurbcu' target="_blank">https://wandb.ai/lrast/TTA/runs/0cfurbcu</a><br/> View project at: <a href='https://wandb.ai/lrast/TTA' target="_blank">https://wandb.ai/lrast/TTA</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250922_100745-0cfurbcu/logs</code>

# %% [markdown]
# This trainer doesn't save all of the weights, just the embedding model weights, so we'll have to load them manually.

# %%
from safetensors import safe_open

post_train = {}
with safe_open(f'vit2_full_sync_raw/checkpoint-7820/model.safetensors', framework="pt", device='cpu') as f:
    for key in f.keys():
        post_train[key] = f.get_tensor(key)


pre_train = {}
with safe_open(f'vit2_full/checkpoint-37500/model.safetensors', framework="pt", device='cpu') as f:
    for key in f.keys():
        pre_train[key] = f.get_tensor(key)

# %%
pre_train.keys()
# Out:
# dict_keys(['classifier.classifier.bias', 'classifier.classifier.weight', 'classifier.vit.encoder.layer.0.attention.attention.key.bias', 'classifier.vit.encoder.layer.0.attention.attention.key.weight', 'classifier.vit.encoder.layer.0.attention.attention.query.bias', 'classifier.vit.encoder.layer.0.attention.attention.query.weight', 'classifier.vit.encoder.layer.0.attention.attention.value.bias', 'classifier.vit.encoder.layer.0.attention.attention.value.weight', 'classifier.vit.encoder.layer.0.attention.output.dense.bias', 'classifier.vit.encoder.layer.0.attention.output.dense.weight', 'classifier.vit.encoder.layer.0.intermediate.dense.bias', 'classifier.vit.encoder.layer.0.intermediate.dense.weight', 'classifier.vit.encoder.layer.0.layernorm_after.bias', 'classifier.vit.encoder.layer.0.layernorm_after.weight', 'classifier.vit.encoder.layer.0.layernorm_before.bias', 'classifier.vit.encoder.layer.0.layernorm_before.weight', 'classifier.vit.encoder.layer.0.output.dense.bias', 'classifier.vit.encoder.layer.0.output.dense.weight', 'classifier.vit.encoder.layer.1.attention.attention.key.bias', 'classifier.vit.encoder.layer.1.attention.attention.key.weight', 'classifier.vit.encoder.layer.1.attention.attention.query.bias', 'classifier.vit.encoder.layer.1.attention.attention.query.weight', 'classifier.vit.encoder.layer.1.attention.attention.value.bias', 'classifier.vit.encoder.layer.1.attention.attention.value.weight', 'classifier.vit.encoder.layer.1.attention.output.dense.bias', 'classifier.vit.encoder.layer.1.attention.output.dense.weight', 'classifier.vit.encoder.layer.1.intermediate.dense.bias', 'classifier.vit.encoder.layer.1.intermediate.dense.weight', 'classifier.vit.encoder.layer.1.layernorm_after.bias', 'classifier.vit.encoder.layer.1.layernorm_after.weight', 'classifier.vit.encoder.layer.1.layernorm_before.bias', 'classifier.vit.encoder.layer.1.layernorm_before.weight', 'classifier.vit.encoder.layer.1.output.dense.bias', 'classifier.vit.encoder.layer.1.output.dense.weight', 'classifier.vit.layernorm.bias', 'classifier.vit.layernorm.weight', 'embedding.decoder.decoder_embed.bias', 'embedding.decoder.decoder_embed.weight', 'embedding.decoder.decoder_layers.0.attention.attention.key.bias', 'embedding.decoder.decoder_layers.0.attention.attention.key.weight', 'embedding.decoder.decoder_layers.0.attention.attention.query.bias', 'embedding.decoder.decoder_layers.0.attention.attention.query.weight', 'embedding.decoder.decoder_layers.0.attention.attention.value.bias', 'embedding.decoder.decoder_layers.0.attention.attention.value.weight', 'embedding.decoder.decoder_layers.0.attention.output.dense.bias', 'embedding.decoder.decoder_layers.0.attention.output.dense.weight', 'embedding.decoder.decoder_layers.0.intermediate.dense.bias', 'embedding.decoder.decoder_layers.0.intermediate.dense.weight', 'embedding.decoder.decoder_layers.0.layernorm_after.bias', 'embedding.decoder.decoder_layers.0.layernorm_after.weight', 'embedding.decoder.decoder_layers.0.layernorm_before.bias', 'embedding.decoder.decoder_layers.0.layernorm_before.weight', 'embedding.decoder.decoder_layers.0.output.dense.bias', 'embedding.decoder.decoder_layers.0.output.dense.weight', 'embedding.decoder.decoder_layers.1.attention.attention.key.bias', 'embedding.decoder.decoder_layers.1.attention.attention.key.weight', 'embedding.decoder.decoder_layers.1.attention.attention.query.bias', 'embedding.decoder.decoder_layers.1.attention.attention.query.weight', 'embedding.decoder.decoder_layers.1.attention.attention.value.bias', 'embedding.decoder.decoder_layers.1.attention.attention.value.weight', 'embedding.decoder.decoder_layers.1.attention.output.dense.bias', 'embedding.decoder.decoder_layers.1.attention.output.dense.weight', 'embedding.decoder.decoder_layers.1.intermediate.dense.bias', 'embedding.decoder.decoder_layers.1.intermediate.dense.weight', 'embedding.decoder.decoder_layers.1.layernorm_after.bias', 'embedding.decoder.decoder_layers.1.layernorm_after.weight', 'embedding.de ...

# %%
decoder_counts = [0, 0]
encoder_counts = [0, 0]

for key, value in post_train.items():
    to_add = int((value == pre_train['embedding.'+key]).all())

    submodel = key.split('.')[0]
    if submodel == 'decoder':
        decoder_counts[to_add] += 1
    elif submodel == 'vit':
        encoder_counts[to_add] += 1
    else:
        print(submodel)

# %%
decoder_counts
# Out:
# [136, 0]

# %%
encoder_counts
# Out:
# [0, 198]

# %% [markdown]
# Perfect: the decoder parameters were updated, the encoder parameters were not.
#
# Update the values in the model with a classifier.

# %%
synchronized = ClassifierWithTTA.load_from_file('vit2_full/checkpoint-37500/', classifier_hidden_layers=2)
# Out:
# Successfully loaded weights from vit2_full/checkpoint-37500/

# %%
for key, value in post_train.items():
    pre_train['embedding.'+key] = value

# %%
synchronized.load_state_dict(pre_train)
# Out:
# <All keys matched successfully>

# %%
from safetensors.torch import save_file
save_file(synchronized.state_dict(), 'vit2_full_sync/model.safetensors')

# %% [markdown]
# ### MAE loss of different setups

# %%
untouched_MAE = ClassifierWithTTA.load_from_file('vit2_probe/checkpoint-62500/', classifier_hidden_layers=2)
unsynchronized = ClassifierWithTTA.load_from_file('vit2_full/checkpoint-37500/', classifier_hidden_layers=2)
synchronized = ClassifierWithTTA.load_from_file('vit2_full_sync/', classifier_hidden_layers=2)
# Out:
# Successfully loaded weights from vit2_probe/checkpoint-62500/
# Successfully loaded weights from vit2_full/checkpoint-37500/
# Successfully loaded weights from vit2_full_sync/

# %%
for name, model in [('untouched', untouched_MAE), ('unsynchronized', unsynchronized), ('synchronized', synchronized)]:
    evaluator = decoder_synchronization_training(model, train, val, report_to="none")
    print( f'{name} loss" {evaluator.evaluate()['eval_loss']}')
# Out:
# /Users/luke/.local/defaultPythonEnv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='1250' max='1250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1250/1250 00:44]
#     </div>
# untouched loss" 0.18352417647838593
#     <div>
#
#       <progress value='1250' max='1250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1250/1250 00:44]
#     </div>
# unsynchronized loss" 0.26832860708236694
#     <div>
#
#       <progress value='1250' max='1250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1250/1250 00:44]
#     </div>
# synchronized loss" 0.18835443258285522

# %% [markdown]
# Synchronization, while not perfect, does bring the loss into line with the reconstruction loss before the encoder was fine-tuned.

# %% [markdown]
# #### double check

# %%
pre_train = unsynchronized.state_dict()
post_train = synchronized.state_dict()

decoder_counts = [0, 0]
encoder_counts = [0, 0]
classifier_counts = [0, 0]

for key, value in post_train.items():
    to_add = int((value == pre_train[key]).all())

    model_spec = key.split('.')

    if model_spec[0] == 'classifier':
        classifier_counts[to_add] += 1
    elif model_spec[0] == 'embedding':
        if model_spec[1] == 'vit':
            encoder_counts[to_add] += 1
        elif model_spec[1] == 'decoder':
            decoder_counts[to_add] += 1
        else:
            print(model_spec)
    else:
        print(model_spec)

# %%
classifier_counts
# Out:
# [0, 36]

# %%
encoder_counts
# Out:
# [0, 198]

# %%
decoder_counts
# Out:
# [136, 0]

# %% [markdown]
# Yep, only the decoder is changed.
#
# #### Now to double check the TTA results in this case.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
import numpy as np

synced_TTA = pd.read_csv('synced_decoder_TTA.csv')

# %%
figsize(5,5)
xs = list(range(0,11))
for i, row in synced_TTA.iterrows():
    ys = [row[f'step{i}'] for i in range(0, 11)]
    plt.plot(xs, ys, label=row['corruption'])
    plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.xlabel('Number of Steps')
plt.ylabel('Accuracy')
_=plt.title('TTA accuracy - probe model')
plt.savefig('figures/adaptation_curves.png', bbox_inches='tight')

# %%
figsize(15, 5)
plt.subplots(1,3)
plt.suptitle('Split according to whether the initial point is highest, lowest, or other.')

plt.subplot(1,3,1)
plt.title('Increasing')
plt.ylim([0, 0.7])
plt.subplot(1,3,2)
plt.title('Harmful')
plt.ylim([0, 0.7])
plt.subplot(1,3,3)
plt.title('Recovering')
plt.ylim([0, 0.7])

xs = list(range(0, 11))
for i, row in synced_TTA.iterrows():
    ys = [row[f'step{i}'] for i in range(11)]
    if np.array(ys).argmin() == 0:
        plt.subplot(1,3,1)
    else:
        if np.array(ys).argmax() == 0:
            plt.subplot(1,3,2)
        else:
            plt.subplot(1,3,3)

    plt.plot(xs, ys, label=row['corruption'])
    plt.legend()

# %% [markdown]
# Firstly, it's worth noting that we see some of the best generalization performances yet observed. There are a couple of decreases, but these are quite weak.
#
# I think that it is still worth sticking with this system, but these results mean that the illustration will likely be much less dramatic.

# %%
uncorrupted_TTA = pd.read_csv('uncorrupted_TTA.csv')

# %%
figsize(5,5)
xs = list(range(0,11))
for i, row in uncorrupted_TTA.iterrows():
    ys = [row[f'step{i}'] for i in range(0, 11)]
    plt.plot(xs, ys, label=f'sample_group{i}')
    plt.legend(bbox_to_anchor=(1.05, 1.05))

plt.xlabel('Number of Steps')
plt.ylabel('Accuracy')
_=plt.title('TTA accuracy - Uncorrupted data')
plt.savefig('figures/adaptation_curves.png', bbox_inches='tight')
plt.ylim([0.6, 0.85])
# Out:
# (0.6, 0.85)

# %% [markdown]
# Note that, because the validation set is sorted by label, these sample groups correspond roughly to pairs of labels.

# %%
running = uncorrupted_TTA.loc[0]

for i, row in uncorrupted_TTA.iterrows():
    if i != 0:
        running += row

# %%
means = running.drop(['model_name', 'corruption']) / len(uncorrupted_TTA)

# %%
ys = [means[f'step{i}'] for i in range(11)]
plt.plot(range(11), ys)
plt.ylim([0.6, 0.8])
# Out:
# (0.6, 0.8)

# %% [markdown]
# TTA on uncorrupted data appears to have a quite small effect, with the shape of the overall curve resembling the general form of TTA curves.
#
# However, based on the variance between categories, there are likely images that both improve and decrease under TTA, meaning that there will likely be enough signal
